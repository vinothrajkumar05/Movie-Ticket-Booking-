# %% [markdown]
# <a href="https://colab.research.google.com/github/vinothrajkumar05/Movie-Ticket-Booking-/blob/main/MOVIE_TICKET_BOOKING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dnspython
# !pip install pymongo[srv]
# !pip install pillow

import pymongo
from pymongo import MongoClient
from PIL import Image
import io
import pandas as pd

client = pymongo.MongoClient("mongodb+srv://vinothdb:1234@cluster0.pzghf.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client.test
movie=db.movie

def registration():
  profile=input(" Enter photo URL:")
  im=Image.open(profile)
  image_bytes=io.BytesIO()
  im.save(image_bytes,format='JPEG')
  name=input("Enter name")
  mail_id=input("Enter E-mail-id:")
  phone=("Enter phone number")
  password=("Enter your password")
  a={
      "profile":image_bytes.getvalue()
      "name":name,
      "E-mail":mail_id,
      "phone":phone,
      "password":password,
  }
  movie.insert_one(a)
  print("Registration successful")
  welcome()

# this theater function used to select screen
def theater():
    print("which screen do you want to watch movie: ")
    print("1,SPIDERMAN")
    print("2,KGF2")
    print("3,PUSHPA")
    print("4,VALIMAI")
    print("5,BEAST")
    a = int(input("choose your screen: "))
    ticket = int(input("number of ticket do you want?: "))
    timing(a)
 
# this timing function used to select timing for movie
def timing(a):
    time1 = {
        "1": "morning",
        "2": "evening",
    }
    time2 = {
        "1": "morning",
        "2": "evening",
      }
    time3 = {
        "1": "morning",
        "2": "evening",
    }
    time4 = {
        "1": "morning",
        "2": "evening",
      }
    time5 = {
        "1": "morning",
        "2": "evening",
    }
    if a == 1:
        print("choose your time:")
        print(time1)
        t = input("select your time:")
        x = time1[t]
        print("successful!, enjoy movie at "+x)
    elif a == 2:
        print("choose your time:")
        print(time2)
        t = input("select your time:")
        x = time2[t]
        print("successful!, enjoy movie at "+x)
    elif a == 3:
        print("choose your time:")
        print(time3)
        t = input("select your time:")
        x = time3[t]
        print("successful!, enjoy movie at "+x)
    elif a == 4:
        print("choose your time:")
        print(time4)
        t = input("select your time:")
        x = time4[t]
        print("successful!, enjoy movie at "+x)
    elif a == 5:
        print("choose your time:")
        print(time5)
        t = input("select your time:")
        x = time5[t]
        print("successful!, enjoy movie at "+x)
    return 0
 
 
def movie(theater):
    if theater == 1:
        t_movie()
    elif theater == 2:
        t_movie()
    elif theater == 3:
        t_movie()
    elif theater == 4:
        t_movie()
    elif theater == 5:
        t_movie()
    elif theater == 6:
        city()
    else:
        print("wrong choice")
 
 
def center():
    print("which theater do you wish to see movie? ")
    print("1,Inox")
    print("2,Babu")
    print("3,pvr")
    print("4,sangam")
    print("5,sathyam")
    a = int(input("choose your option: "))
    movie(a)
    return 0
 
# this function is used to select city
def city():
    print("Hi welcome to movie ticket booking: ")
    print("where you want to watch movie?:")
    print("1,city 1")
    print("2,city 2 ")
    print("3,city 3 ")
    print("4,city 4 ")
    print("5,city 5 ")
    place = int(input("choose your option: "))
    if place == 1:
      center()
    elif place == 2:
      center()
    elif place == 3:
      center()
    elif place == 4:
      center()
    elif place == 5:
      center()
    else:
      print("wrong choice")
# !pip install qrcode
import qrcode
img = qrcode.make('CBFC U/A')
type(img)  # qrcode.image.pil.PilImage
img.save("/content/PHOTO-min-min.jpg")
# Out:
#   File "<ipython-input-21-603cb4f18f6f>", line 26
#     "name":name,
#          ^
# SyntaxError: invalid syntax
